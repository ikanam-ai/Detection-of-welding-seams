# %%
import os
import cv2

def draw_bounding_box(image, box, class_id, class_names, color=(255, 0, 0), box_thickness=1, font_scale=0.5, font_thickness=1):
    """
    Рисует bounding box на изображении.
    
    image: изображение в формате numpy array
    box: кортеж (x_center, y_center, width, height) в формате YOLO
    class_id: идентификатор класса
    class_names: список имен классов
    color: цвет bounding box и текста (по умолчанию синий)
    box_thickness: толщина линий bounding box
    font_scale: масштаб шрифта для текста
    font_thickness: толщина шрифта для текста
    """
    height, width, _ = image.shape
    x_center, y_center, w, h = box
    
    # Преобразование из нормализованных координат YOLO в пиксели
    xmin = int((x_center - w / 2) * width)
    xmax = int((x_center + w / 2) * width)
    ymin = int((y_center - h / 2) * height)
    ymax = int((y_center + h / 2) * height)
    
    # Убедимся, что координаты находятся в пределах изображения
    xmin = max(0, xmin)
    ymin = max(0, ymin)
    xmax = min(width, xmax)
    ymax = min(height, ymax)
    
    cv2.rectangle(image, (xmin, ymin), (xmax, ymax), color, int(box_thickness))
    
    label = f"{class_names[class_id]}"
    (label_width, label_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, font_scale, int(font_thickness))
    
    # Рисуем фон для текста
    cv2.rectangle(image, (xmin, ymin - label_height - baseline), (xmin + label_width, ymin), color, cv2.FILLED)
    # Рисуем текст
    cv2.putText(image, label, (xmin, ymin - baseline), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), int(font_thickness))

def visualize_annotations(image_path, annotation_path, class_names, color=(255, 0, 0), box_thickness=1, font_scale=0.5, font_thickness=1):
    """
    Визуализирует аннотации на изображении.
    
    image_path: путь к изображению
    annotation_path: путь к YOLO файлу аннотаций
    class_names: список имен классов
    color: цвет bounding box и текста (по умолчанию синий)
    box_thickness: толщина линий bounding box
    font_scale: масштаб шрифта для текста
    font_thickness: толщина шрифта для текста
    """
    image = cv2.imread(image_path)
    if image is None:
        print(f"Could not read image {image_path}")
        return None
    
    try:
        with open(annotation_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    print(f"Skipping invalid annotation in {annotation_path}: {line.strip()}")
                    continue
                class_id = int(parts[0])
                box = tuple(map(float, parts[1:]))
                draw_bounding_box(image, box, class_id, class_names, color, box_thickness, font_scale, font_thickness)
    except Exception as e:
        print(f"Error processing {annotation_path}: {e}")
        return None
    
    return image  # Возвращаем изображение с аннотациями

def process_directory(images_dir, annotations_dir, output_dir, class_names, color=(255, 0, 0), box_thickness=1, font_scale=0.5, font_thickness=1):
    """
    Обрабатывает все изображения в директории и визуализирует аннотации.
    
    images_dir: директория с изображениями
    annotations_dir: директория с YOLO файлами аннотаций
    output_dir: директория для сохранения визуализированных изображений
    class_names: список имен классов
    color: цвет bounding box и текста (по умолчанию синий)
    box_thickness: толщина линий bounding box
    font_scale: масштаб шрифта для текста
    font_thickness: толщина шрифта для текста
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    image_files.sort()  # Сортируем для сохранения порядка

    for image_name in image_files:
        image_path = os.path.join(images_dir, image_name)
        annotation_name = f"{os.path.splitext(image_name)[0]}.txt"
        annotation_path = os.path.join(annotations_dir, annotation_name)
        
        if os.path.exists(annotation_path):
            print(f"Processing {image_name}")
            annotated_image = visualize_annotations(image_path, annotation_path, class_names, color, box_thickness, font_scale, font_thickness)
            
            if annotated_image is not None:
                output_image_path = os.path.join(output_dir, image_name)
                cv2.imwrite(output_image_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
        else:
            print(f"Annotation not found for {image_name}")

# Пример использования:


# Пример использования:

# %%
images_dir = '/home/andrew/works/shpad_add/Detection-of-welding-seams/dataset_copy_2/images'  # Замените на путь к директории с изображениями
annotations_dir = '/home/andrew/works/shpad_add/Detection-of-welding-seams/dataset_copy_2/labels'  # Замените на путь к директории с YOLO аннотациями
output_dir = '//home/andrew/works/shpad_add/Detection-of-welding-seams/dataset_risovashka'  # Замените на путь к директории для сохранения визуализированных изображений
class_names = ['adj', 'int', 'geo', 'pro', 'non']

# Параметры визуализации
color = (255, 0, 0)  # Цвет для bounding box и текста (синий)
box_thickness = 2.5   # Толщина линий bounding box
font_scale = 1.5    # Масштаб шрифта для текста
font_thickness = 2   # Толщина шрифта для текста

# %%
process_directory(images_dir, annotations_dir, output_dir, class_names, color, box_thickness, font_scale, font_thickness)
# Out:
# Processing 1 (1).jpg
# Processing 1 (10).jpg
# Processing 1 (11).jpg
# Processing 1 (12).jpg
# Processing 1 (13).jpg
# Processing 1 (2).jpg
# Processing 1 (3).jpg
# Processing 1 (4).jpg
# Processing 1 (5).jpg
# Processing 1 (6).jpg
# Processing 1 (7).jpg
# Processing 1 (8).jpg
# Processing 1 (9).jpg
# Processing 11 (1).jpg
# Processing 11 (10).jpg
# Processing 11 (11).jpg
# Processing 11 (12).jpg
# Processing 11 (13).jpg
# Processing 11 (14).jpg
# Processing 11 (15).jpg
# Processing 11 (16).jpg
# Processing 11 (17).jpg
# Processing 11 (18).jpg
# Processing 11 (19).jpg
# Processing 11 (2).jpg
# Processing 11 (20).jpg
# Processing 11 (21).jpg
# Processing 11 (22).jpg
# Processing 11 (23).jpg
# Processing 11 (24).jpg
# Processing 11 (25).jpg
# Processing 11 (26).jpg
# Processing 11 (27).jpg
# Processing 11 (28).jpg
# Processing 11 (29).jpg
# Processing 11 (3).jpg
# Processing 11 (30).jpg
# Processing 11 (31).jpg
# Processing 11 (32).jpg
# Processing 11 (33).jpg
# Processing 11 (34).jpg
# Processing 11 (35).jpg
# Processing 11 (36).jpg
# Processing 11 (37).jpg
# Processing 11 (38).jpg
# Processing 11 (39).jpg
# Processing 11 (4).jpg
# Processing 11 (40).jpg
# Processing 11 (41).jpg
# Processing 11 (42).jpg
# Processing 11 (43).jpg
# Processing 11 (44).jpg
# Processing 11 (45).jpg
# Processing 11 (46).jpg
# Processing 11 (47).jpg
# Processing 11 (48).jpg
# Processing 11 (49).jpg
# Processing 11 (5).jpg
# Processing 11 (50).jpg
# Processing 11 (51).jpg
# Processing 11 (52).jpg
# Processing 11 (53).jpg
# Processing 11 (54).jpg
# Processing 11 (55).jpg
# Processing 11 (56).jpg
# Processing 11 (57).jpg
# Processing 11 (58).jpg
# Processing 11 (59).jpg
# Processing 11 (6).jpg
# Processing 11 (60).jpg
# Processing 11 (61).jpg
# Processing 11 (62).jpg
# Processing 11 (63).jpg
# Processing 11 (64).jpg
# Processing 11 (65).jpg
# Processing 11 (66).jpg
# Processing 11 (67).jpg
# Processing 11 (68).jpg
# Processing 11 (69).jpg
# Processing 11 (7).jpg
# Processing 11 (70).jpg
# Processing 11 (71).jpg
# Processing 11 (72).jpg
# Processing 11 (73).jpg
# Processing 11 (74).jpg
# Processing 11 (75).jpg
# Processing 11 (76).jpg
# Processing 11 (78).jpg
# Processing 11 (79).jpg
# Processing 11 (8).jpg
# Processing 11 (80).jpg
# Processing 11 (81).jpg
# Processing 11 (82).jpg
# Processing 11 (83).jpg
# Processing 11 (9).jpg
# Processing 12 (1).jpg
# Processing 12 (10).jpg
# Processing 12 (11).jpg
# Processing 12 (12).jpg
# Processing 12 (13).jpg
# Processing 12 (14).jpg
# Processing 12 (15).jpg
# Processing 12 (16).jpg
# Processing 12 (17).jpg
# Processing 12 (18).jpg
# Processing 12 (19).jpg
# Processing 12 (2).jpg
# Processing 12 (20).jpg
# Processing 12 (21).jpg
# Processing 12 (22).jpg
# Processing 12 (23).jpg
# Processing 12 (24).jpg
# Processing 12 (25).jpg
# Processing 12 (26).jpg
# Processing 12 (27).jpg
# Processing 12 (28).jpg
# Processing 12 (29).jpg
# Processing 12 (3).jpg
# Processing 12 (30).jpg
# Processing 12 (31).jpg
# Processing 12 (32).jpg
# Processing 12 (36).jpg
# Processing 12 (37).jpg
# Processing 12 (38).jpg
# Processing 12 (4).jpg
# Processing 12 (41).jpg
# Processing 12 (42).jpg
# Processing 12 (43).jpg
# Processing 12 (48).jpg
# Processing 12 (49).jpg
# Processing 12 (5).jpg
# Processing 12 (50).jpg
# Processing 12 (51).jpg
# Processing 12 (52).jpg
# Processing 12 (55).jpg
# Processing 12 (56).jpg
# Processing 12 (57).jpg
# Processing 12 (58).jpg
# Processing 12 (59).jpg
# Processing 12 (6).jpg
# Processing 12 (60).jpg
# Processing 12 (67).jpg
# Processing 12 (68).jpg
# Processing 12 (69).jpg
# Processing 12 (7).jpg
# Processing 12 (70).jpg
# Processing 12 (71).jpg
# Processing 12 (72).jpg
# Processing 12 (73).jpg
# Processing 12 (74).jpg
# Processing 12 (77).jpg
# Processing 12 (78).jpg
# Processing 12 (79).jpg
# Processing 12 (8).jpg
# Processing 12 (80).jpg
# Processing 12 (81).jpg
# Processing 12 (82).jpg
# Processing 12 (9).jpg
# Processing 2 (1).jpg
# Processing 2 (10).jpg
# Processing 2 (11).jpg
# Processing 2 (12).jpg
# Processing 2 (13).jpg
# Processing 2 (2).jpg
# Processing 2 (3).jpg
# Processing 2 (4).jpg
# Processing 2 (5).jpg
# Processing 2 (6).jpg
# Processing 2 (7).jpg
# Processing 2 (8).jpg
# Processing 2 (9).jpg
# Processing 3 (1).jpg
# Processing 3 (10).jpg
# Processing 3 (11).jpg
# Processing 3 (12).jpg
# Processing 3 (13).jpg
# Processing 3 (14).jpg
# Processing 3 (15).jpg
# Processing 3 (16).jpg
# Processing 3 (17).jpg
# Processing 3 (18).jpg
# Processing 3 (19).jpg
# Processing 3 (2).jpg
# Processing 3 (20).jpg
# Processing 3 (21).jpg
# Processing 3 (22).jpg
# Processing 3 (23).jpg
# Processing 3 (24).jpg
# Processing 3 (25).jpg
# Processing 3 (26).jpg
# Processing 3 (27).jpg
# Processing 3 (28).jpg
# Processing 3 (29).jpg
# Processing 3 (3).jpg
# Processing 3 (30).jpg
# Processing 3 (31).jpg
# Processing 3 (32).jpg
# Processing 3 (33).jpg
# Processing 3 (34).jpg
# Processing 3 (35).jpg
# Processing 3 (36).jpg
# Processing 3 (37).jpg
# Processing 3 (38).jpg
# Processing 3 (39).jpg
# Processing 3 (4).jpg
# Processing 3 (40).jpg
# Processing 3 (41).jpg
# Processing 3 (42).jpg
# Processing 3 (43).jpg
# Processing 3 (44).jpg
# Processing 3 (45).jpg
# Processing 3 (46).jpg
# Processing 3 (47).jpg
# Processing 3 (48).jpg
# Processing 3 (49).jpg
# Processing 3 (5).jpg
# Processing 3 (50).jpg
# Processing 3 (51).jpg
# Processing 3 (6).jpg
# Processing 3 (7).jpg
# Processing 3 (8).jpg
# Processing 3 (9).jpg
# Processing 4 (1).jpg
# Processing 4 (10).jpg
# Processing 4 (100).jpg
# Processing 4 (101).jpg
# Processing 4 (102).jpg
# Processing 4 (103).jpg
# Processing 4 (104).jpg
# Processing 4 (105).jpg
# Processing 4 (106).jpg
# Processing 4 (107).jpg
# Processing 4 (108).jpg
# Processing 4 (109).jpg
# Processing 4 (11).jpg
# Processing 4 (110).jpg
# Processing 4 (111).jpg
# Processing 4 (112).jpg
# Processing 4 (113).jpg
# Processing 4 (114).jpg
# Processing 4 (115).jpg
# Processing 4 (116).jpg
# Processing 4 (117).jpg
# Processing 4 (118).jpg
# Processing 4 (119).jpg
# Processing 4 (12).jpg
# Processing 4 (120).jpg
# Processing 4 (121).jpg
# Processing 4 (122).jpg
# Processing 4 (123).jpg
# Processing 4 (124).jpg
# Processing 4 (125).jpg
# Processing 4 (126).jpg
# Processing 4 (127).jpg
# Processing 4 (128).jpg
# Processing 4 (129).jpg
# Processing 4 (13).jpg
# Processing 4 (130).jpg
# Processing 4 (131).jpg
# Processing 4 (132).jpg
# Processing 4 (133).jpg
# Processing 4 (134).jpg
# Processing 4 (135).jpg
# Processing 4 (136).jpg
# Processing 4 (137).jpg
# Processing 4 (138).jpg
# Processing 4 (139).jpg
# Processing 4 (14).jpg
# Processing 4 (140).jpg
# Processing 4 (141).jpg
# Processing 4 (142).jpg
# Processing 4 (143).jpg
# Processing 4 (144).jpg
# Processing 4 (145).jpg
# Processing 4 (146).jpg
# Processing 4 (147).jpg
# Processing 4 (148).jpg
# Processing 4 (149).jpg
# Processing 4 (15).jpg
# Processing 4 (150).jpg
# Processing 4 (151).jpg
# Processing 4 (152).jpg
# Processing 4 (16).jpg
# Processing 4 (17).jpg
# Processing 4 (18).jpg
# Processing 4 (19).jpg
# Processing 4 (2).jpg
# Processing 4 (20).jpg
# Processing 4 (21).jpg
# Processing 4 (22).jpg
# Processing 4 (23).jpg
# Processing 4 (24).jpg
# Processing 4 (25).jpg
# Processing 4 (26).jpg
# Processing 4 (27).jpg
# Processing 4 (28).jpg
# Processing 4 (29).jpg
# Processing 4 (3).jpg
# Processing 4 (30).jpg
# Processing 4 (31).jpg
# Processing 4 (32).jpg
# Processing 4 (33).jpg
# Processing 4 (34).jpg
# Processing 4 (35).jpg
# Processing 4 (36).jpg
# Processing 4 (37).jpg
# Processing 4 (38).jpg
# Processing 4 (39).jpg
# Processing 4 (4).jpg
# Processing 4 (40).jpg
# Processing 4 (41).jpg
# Processing 4 (42).jpg
# Processing 4 (43).jpg
# Processing 4 (44).jpg
# Processing 4 (45).jpg
# Processing 4 (46).jpg
# Processing 4 (47).jpg
# Processing 4 (48).jpg
# Processing 4 (49).jpg
# Processing 4 (5).jpg
# Processing 4 (50).jpg
# Processing 4 (51).jpg
# Processing 4 (52).jpg
# Processing 4 (53).jpg
# Processing 4 (54).jpg
# Processing 4 (55).jpg
# Processing 4 (56).jpg
# Processing 4 (57).jpg
# Processing 4 (58).jpg
# Processing 4 (59).jpg
# Processing 4 (6).jpg
# Processing 4 (60).jpg
# Processing 4 (61).jpg
# Processing 4 (62).jpg
# Processing 4 (63).jpg
# Processing 4 (64).jpg
# Processing 4 (65).jpg
# Processing 4 (66).jpg
# Processing 4 (67).jpg
# Processing 4 (68).jpg
# Processing 4 (69).jpg
# Processing 4 (7).jpg
# Processing 4 (70).jpg
# Processing 4 (71).jpg
# Processing 4 (72).jpg
# Processing 4 (73).jpg
# Processing 4 (74).jpg
# Processing 4 (75).jpg
# Processing 4 (76).jpg
# Processing 4 (77).jpg
# Processing 4 (78).jpg
# Processing 4 (79).jpg
# Processing 4 (8).jpg
# Processing 4 (80).jpg
# Processing 4 (81).jpg
# Processing 4 (82).jpg
# Processing 4 (83).jpg
# Processing 4 (84).jpg
# Processing 4 (85).jpg
# Processing 4 (86).jpg
# Processing 4 (87).jpg
# Processing 4 (88).jpg
# Processing 4 (89).jpg
# Processing 4 (9).jpg
# Processing 4 (90).jpg
# Processing 4 (91).jpg
# Processing 4 (92).jpg
# Processing 4 (93).jpg
# Processing 4 (94).jpg
# Processing 4 (95).jpg
# Processing 4 (96).jpg
# Processing 4 (97).jpg
# Processing 4 (98).jpg
# Processing 4 (99).jpg
# Processing 5 (1).jpg
# Processing 5 (10).jpg
# Processing 5 (100).jpg
# Processing 5 (101).jpg
# Processing 5 (102).jpg
# Processing 5 (103).jpg
# Processing 5 (104).jpg
# Processing 5 (105).jpg
# Processing 5 (106).jpg
# Processing 5 (107).jpg
# Processing 5 (108).jpg
# Processing 5 (109).jpg
# Processing 5 (11).jpg
# Processing 5 (110).jpg
# Processing 5 (111).jpg
# Processing 5 (112).jpg
# Processing 5 (113).jpg
# Processing 5 (114).jpg
# Processing 5 (115).jpg
# Processing 5 (116).jpg
# Processing 5 (117).jpg
# Processing 5 (118).jpg
# Processing 5 (119).jpg
# Processing 5 (12).jpg
# Processing 5 (120).jpg
# Processing 5 (121).jpg
# Processing 5 (122).jpg
# Processing 5 (123).jpg
# Processing 5 (124).jpg
# Processing 5 (125).jpg
# Processing 5 (126).jpg
# Processing 5 (127).jpg
# Processing 5 (128).jpg
# Processing 5 (129).jpg
# Processing 5 (13).jpg
# Processing 5 (130).jpg
# Processing 5 (131).jpg
# Processing 5 (132).jpg
# Processing 5 (133).jpg
# Processing 5 (134).jpg
# Processing 5 (135).jpg
# Processing 5 (136).jpg
# Processing 5 (137).jpg
# Processing 5 (138).jpg
# Processing 5 (139).jpg
# Processing 5 (14).jpg
# Processing 5 (140).jpg
# Processing 5 (141).jpg
# Processing 5 (142).jpg
# Processing 5 (143).jpg
# Processing 5 (144).jpg
# Processing 5 (145).jpg
# Processing 5 (146).jpg
# Processing 5 (147).jpg
# Processing 5 (148).jpg
# Processing 5 (149).jpg
# Processing 5 (15).jpg
# Processing 5 (150).jpg
# Processing 5 (151).jpg
# Processing 5 (152).jpg
# Processing 5 (153).jpg
# Processing 5 (154).jpg
# Processing 5 (155).jpg
# Processing 5 (156).jpg
# Processing 5 (157).jpg
# Processing 5 (158).jpg
# Processing 5 (159).jpg
# Processing 5 (16).jpg
# Processing 5 (160).jpg
# Processing 5 (161).jpg
# Processing 5 (162).jpg
# Processing 5 (163).jpg
# Processing 5 (164).jpg
# Processing 5 (165).jpg
# Processing 5 (166).jpg
# Processing 5 (167).jpg
# Processing 5 (168).jpg
# Processing 5 (169).jpg
# Processing 5 (17).jpg
# Processing 5 (170).jpg
# Processing 5 (171).jpg
# Processing 5 (172).jpg
# Processing 5 (173).jpg
# Processing 5 (174).jpg
# Processing 5 (175).jpg
# Processing 5 (176).jpg
# Processing 5 (177).jpg
# Processing 5 (178).jpg
# Processing 5 (179).jpg
# Processing 5 (18).jpg
# Processing 5 (180).jpg
# Processing 5 (181).jpg
# Processing 5 (182).jpg
# Processing 5 (183).jpg
# Processing 5 (184).jpg
# Processing 5 (185).jpg
# Processing 5 (186).jpg
# Processing 5 (187).jpg
# Processing 5 (188).jpg
# Processing 5 (189).jpg
# Processing 5 (19).jpg
# Processing 5 (190).jpg
# Processing 5 (191).jpg
# Processing 5 (192).jpg
# Processing 5 (193).jpg
# Processing 5 (194).jpg
# Processing 5 (195).jpg
# Processing 5 (196).jpg
# Processing 5 (197).jpg
# Processing 5 (198).jpg
# Processing 5 (199).jpg
# Processing 5 (2).jpg
# Processing 5 (20).jpg
# Processing 5 (200).jpg
# Processing 5 (201).jpg
# Processing 5 (202).jpg
# Processing 5 (203).jpg
# Processing 5 (204).jpg
# Processing 5 (205).jpg
# Processing 5 (206).jpg
# Processing 5 (207).jpg
# Processing 5 (208).jpg
# Processing 5 (209).jpg
# Processing 5 (21).jpg
# Processing 5 (210).jpg
# Processing 5 (211).jpg
# Processing 5 (212).jpg
# Processing 5 (213).jpg
# Processing 5 (214).jpg
# Processing 5 (215).jpg
# Processing 5 (216).jpg
# Processing 5 (217).jpg
# Processing 5 (218).jpg
# Processing 5 (219).jpg
# Processing 5 (22).jpg
# Processing 5 (220).jpg
# Processing 5 (221).jpg
# Processing 5 (222).jpg
# Processing 5 (223).jpg
# Processing 5 (224).jpg
# Processing 5 (23).jpg
# Processing 5 (24).jpg
# Processing 5 (25).jpg
# Processing 5 (26).jpg
# Processing 5 (27).jpg
# Processing 5 (28).jpg
# Processing 5 (29).jpg
# Processing 5 (3).jpg
# Processing 5 (30).jpg
# Processing 5 (31).jpg
# Processing 5 (32).jpg
# Processing 5 (33).jpg
# Processing 5 (34).jpg
# Processing 5 (35).jpg
# Processing 5 (36).jpg
# Processing 5 (37).jpg
# Processing 5 (38).jpg
# Processing 5 (39).jpg
# Processing 5 (4).jpg
# Processing 5 (40).jpg
# Processing 5 (41).jpg
# Processing 5 (42).jpg
# Processing 5 (43).jpg
# Processing 5 (44).jpg
# Processing 5 (45).jpg
# Processing 5 (46).jpg
# Processing 5 (47).jpg
# Processing 5 (48).jpg
# Processing 5 (49).jpg
# Processing 5 (5).jpg
# Processing 5 (50).jpg
# Processing 5 (51).jpg
# Processing 5 (52).jpg
# Processing 5 (53).jpg
# Processing 5 (54).jpg
# Processing 5 (55).jpg
# Processing 5 (56).jpg
# Processing 5 (57).jpg
# Processing 5 (58).jpg
# Processing 5 (59).jpg
# Processing 5 (6).jpg
# Processing 5 (60).jpg
# Processing 5 (61).jpg
# Processing 5 (62).jpg
# Processing 5 (63).jpg
# Processing 5 (64).jpg
# Processing 5 (65).jpg
# Processing 5 (66).jpg
# Processing 5 (67).jpg
# Processing 5 (68).jpg
# Processing 5 (69).jpg
# Processing 5 (7).jpg
# Processing 5 (70).jpg
# Processing 5 (71).jpg
# Processing 5 (72).jpg
# Processing 5 (73).jpg
# Processing 5 (74).jpg
# Processing 5 (75).jpg
# Processing 5 (76).jpg
# Processing 5 (77).jpg
# Processing 5 (78).jpg
# Processing 5 (79).jpg
# Processing 5 (8).jpg
# Processing 5 (80).jpg
# Processing 5 (81).jpg
# Processing 5 (82).jpg
# Processing 5 (83).jpg
# Processing 5 (84).jpg
# Processing 5 (85).jpg
# Processing 5 (86).jpg
# Processing 5 (87).jpg
# Processing 5 (88).jpg
# Processing 5 (89).jpg
# Processing 5 (9).jpg
# Processing 5 (90).jpg
# Processing 5 (91).jpg
# Processing 5 (92).jpg
# Processing 5 (93).jpg
# Processing 5 (94).jpg
# Processing 5 (95).jpg
# Processing 5 (96).jpg
# Processing 5 (97).jpg
# Processing 5 (98).jpg
# Processing 5 (99).jpg
# Processing 6 (1).jpg
# Processing 6 (10).jpg
# Processing 6 (100).jpg
# Processing 6 (101).jpg
# Processing 6 (102).jpg
# Processing 6 (103).jpg
# Processing 6 (104).jpg
# Processing 6 (105).jpg
# Processing 6 (106).jpg
# Processing 6 (107).jpg
# Processing 6 (108).jpg
# Processing 6 (109).jpg
# Processing 6 (11).jpg
# Processing 6 (110).jpg
# Processing 6 (111).jpg
# Processing 6 (12).jpg
# Processing 6 (13).jpg
# Processing 6 (14).jpg
# Processing 6 (15).jpg
# Processing 6 (16).jpg
# Processing 6 (17).jpg
# Processing 6 (18).jpg
# Processing 6 (19).jpg
# Processing 6 (2).jpg
# Processing 6 (20).jpg
# Processing 6 (21).jpg
# Processing 6 (22).jpg
# Processing 6 (23).jpg
# Processing 6 (24).jpg
# Processing 6 (25).jpg
# Processing 6 (26).jpg
# Processing 6 (27).jpg
# Processing 6 (28).jpg
# Processing 6 (29).jpg
# Processing 6 (3).jpg
# Processing 6 (30).jpg
# Processing 6 (31).jpg
# Processing 6 (32).jpg
# Processing 6 (33).jpg
# Processing 6 (34).jpg
# Processing 6 (35).jpg
# Processing 6 (36).jpg
# Processing 6 (37).jpg
# Processing 6 (38).jpg
# Processing 6 (39).jpg
# Processing 6 (4).jpg
# Processing 6 (40).jpg
# Processing 6 (41).jpg
# Processing 6 (42).jpg
# Processing 6 (43).jpg
# Processing 6 (44).jpg
# Processing 6 (45).jpg
# Processing 6 (46).jpg
# Processing 6 (47).jpg
# Processing 6 (48).jpg
# Processing 6 (49).jpg
# Processing 6 (5).jpg
# Processing 6 (50).jpg
# Processing 6 (51).jpg
# Processing 6 (52).jpg
# Processing 6 (53).jpg
# Processing 6 (54).jpg
# Processing 6 (55).jpg
# Processing 6 (56).jpg
# Processing 6 (57).jpg
# Processing 6 (58).jpg
# Processing 6 (59).jpg
# Processing 6 (6).jpg
# Processing 6 (60).jpg
# Processing 6 (61).jpg
# Processing 6 (62).jpg
# Processing 6 (63).jpg
# Processing 6 (64).jpg
# Processing 6 (65).jpg
# Processing 6 (66).jpg
# Processing 6 (67).jpg
# Processing 6 (68).jpg
# Processing 6 (69).jpg
# Processing 6 (7).jpg
# Processing 6 (70).jpg
# Processing 6 (71).jpg
# Processing 6 (72).jpg
# Processing 6 (73).jpg
# Processing 6 (74).jpg
# Processing 6 (75).jpg
# Processing 6 (76).jpg
# Processing 6 (77).jpg
# Processing 6 (78).jpg
# Processing 6 (79).jpg
# Processing 6 (8).jpg
# Processing 6 (80).jpg
# Processing 6 (81).jpg
# Processing 6 (82).jpg
# Processing 6 (83).jpg
# Processing 6 (84).jpg
# Processing 6 (85).jpg
# Processing 6 (86).jpg
# Processing 6 (87).jpg
# Processing 6 (88).jpg
# Processing 6 (89).jpg
# Processing 6 (9).jpg
# Processing 6 (90).jpg
# Processing 6 (91).jpg
# Processing 6 (92).jpg
# Processing 6 (93).jpg
# Processing 6 (94).jpg
# Processing 6 (95).jpg
# Processing 6 (96).jpg
# Processing 6 (97).jpg
# Processing 6 (98).jpg
# Processing 6 (99).jpg
# Processing 7 (1).jpg
# Processing 7 (10).jpg
# Processing 7 (100).jpg
# Processing 7 (101).jpg
# Processing 7 (102).jpg
# Processing 7 (103).jpg
# Processing 7 (104).jpg
# Processing 7 (105).jpg
# Processing 7 (106).jpg
# Processing 7 (107).jpg
# Processing 7 (108).jpg
# Processing 7 (109).jpg
# Processing 7 (11).jpg
# Processing 7 (110).jpg
# Processing 7 (111).jpg
# Processing 7 (112).jpg
# Processing 7 (113).jpg
# Processing 7 (114).jpg
# Processing 7 (115).jpg
# Processing 7 (116).jpg
# Processing 7 (117).jpg
# Processing 7 (118).jpg
# Processing 7 (119).jpg
# Processing 7 (12).jpg
# Processing 7 (120).jpg
# Processing 7 (121).jpg
# Processing 7 (122).jpg
# Processing 7 (123).jpg
# Processing 7 (124).jpg
# Processing 7 (125).jpg
# Processing 7 (126).jpg
# Processing 7 (127).jpg
# Processing 7 (128).jpg
# Processing 7 (129).jpg
# Processing 7 (13).jpg
# Processing 7 (130).jpg
# Processing 7 (131).jpg
# Processing 7 (132).jpg
# Processing 7 (133).jpg
# Processing 7 (134).jpg
# Processing 7 (135).jpg
# Processing 7 (136).jpg
# Processing 7 (137).jpg
# Processing 7 (138).jpg
# Processing 7 (139).jpg
# Processing 7 (14).jpg
# Processing 7 (140).jpg
# Processing 7 (141).jpg
# Processing 7 (142).jpg
# Processing 7 (143).jpg
# Processing 7 (144).jpg
# Processing 7 (145).jpg
# Processing 7 (146).jpg
# Processing 7 (147).jpg
# Processing 7 (148).jpg
# Processing 7 (149).jpg
# Processing 7 (15).jpg
# Processing 7 (150).jpg
# Processing 7 (151).jpg
# Processing 7 (152).jpg
# Processing 7 (153).jpg
# Processing 7 (154).jpg
# Processing 7 (155).jpg
# Processing 7 (156).jpg
# Processing 7 (157).jpg
# Processing 7 (158).jpg
# Processing 7 (159).jpg
# Processing 7 (16).jpg
# Processing 7 (160).jpg
# Processing 7 (161).jpg
# Processing 7 (162).jpg
# Processing 7 (163).jpg
# Processing 7 (164).jpg
# Processing 7 (165).jpg
# Processing 7 (166).jpg
# Processing 7 (167).jpg
# Processing 7 (168).jpg
# Processing 7 (169).jpg
# Processing 7 (17).jpg
# Processing 7 (170).jpg
# Processing 7 (171).jpg
# Processing 7 (172).jpg
# Processing 7 (173).jpg
# Processing 7 (174).jpg
# Processing 7 (175).jpg
# Processing 7 (176).jpg
# Processing 7 (177).jpg
# Processing 7 (178).jpg
# Processing 7 (179).jpg
# Processing 7 (18).jpg
# Processing 7 (180).jpg
# Processing 7 (181).jpg
# Processing 7 (182).jpg
# Processing 7 (183).jpg
# Processing 7 (184).jpg
# Processing 7 (185).jpg
# Processing 7 (186).jpg
# Processing 7 (187).jpg
# Processing 7 (188).jpg
# Processing 7 (189).jpg
# Processing 7 (19).jpg
# Processing 7 (190).jpg
# Processing 7 (191).jpg
# Processing 7 (192).jpg
# Processing 7 (193).jpg
# Processing 7 (194).jpg
# Processing 7 (195).jpg
# Processing 7 (196).jpg
# Processing 7 (197).jpg
# Processing 7 (198).jpg
# Processing 7 (199).jpg
# Processing 7 (2).jpg
# Processing 7 (20).jpg
# Processing 7 (200).jpg
# Processing 7 (201).jpg
# Processing 7 (202).jpg
# Processing 7 (203).jpg
# Processing 7 (204).jpg
# Processing 7 (205).jpg
# Processing 7 (206).jpg
# Processing 7 (207).jpg
# Processing 7 (208).jpg
# Processing 7 (209).jpg
# Processing 7 (21).jpg
# Processing 7 (210).jpg
# Processing 7 (211).jpg
# Processing 7 (212).jpg
# Processing 7 (213).jpg
# Processing 7 (214).jpg
# Processing 7 (215).jpg
# Processing 7 (216).jpg
# Processing 7 (217).jpg
# Processing 7 (218).jpg
# Processing 7 (219).jpg
# Processing 7 (22).jpg
# Processing 7 (220).jpg
# Processing 7 (221).jpg
# Processing 7 (222).jpg
# Processing 7 (223).jpg
# Processing 7 (224).jpg
# Processing 7 (225).jpg
# Processing 7 (226).jpg
# Processing 7 (227).jpg
# Processing 7 (228).jpg
# Processing 7 (229).jpg
# Processing 7 (23).jpg
# Processing 7 (230).jpg
# Processing 7 (231).jpg
# Processing 7 (232).jpg
# Processing 7 (233).jpg
# Processing 7 (234).jpg
# Processing 7 (235).jpg
# Processing 7 (236).jpg
# Processing 7 (237).jpg
# Processing 7 (238).jpg
# Processing 7 (239).jpg
# Processing 7 (24).jpg
# Processing 7 (240).jpg
# Processing 7 (241).jpg
# Processing 7 (242).jpg
# Processing 7 (243).jpg
# Processing 7 (244).jpg
# Processing 7 (245).jpg
# Processing 7 (246).jpg
# Processing 7 (247).jpg
# Processing 7 (248).jpg
# Processing 7 (249).jpg
# Processing 7 (25).jpg
# Processing 7 (250).jpg
# Processing 7 (251).jpg
# Processing 7 (252).jpg
# Processing 7 (253).jpg
# Processing 7 (254).jpg
# Processing 7 (255).jpg
# Processing 7 (256).jpg
# Processing 7 (257).jpg
# Processing 7 (258).jpg
# Processing 7 (259).jpg
# Processing 7 (26).jpg
# Processing 7 (260).jpg
# Processing 7 (261).jpg
# Processing 7 (262).jpg
# Processing 7 (27).jpg
# Processing 7 (28).jpg
# Processing 7 (29).jpg
# Processing 7 (3).jpg
# Processing 7 (30).jpg
# Processing 7 (31).jpg
# Processing 7 (32).jpg
# Processing 7 (33).jpg
# Processing 7 (34).jpg
# Processing 7 (35).jpg
# Processing 7 (36).jpg
# Processing 7 (37).jpg
# Processing 7 (38).jpg
# Processing 7 (39).jpg
# Processing 7 (4).jpg
# Processing 7 (40).jpg
# Processing 7 (41).jpg
# Processing 7 (42).jpg
# Processing 7 (43).jpg
# Processing 7 (44).jpg
# Processing 7 (45).jpg
# Processing 7 (46).jpg
# Processing 7 (47).jpg
# Processing 7 (48).jpg
# Processing 7 (49).jpg
# Processing 7 (5).jpg
# Processing 7 (50).jpg
# Processing 7 (51).jpg
# Processing 7 (52).jpg
# Processing 7 (53).jpg
# Processing 7 (54).jpg
# Processing 7 (55).jpg
# Processing 7 (56).jpg
# Processing 7 (57).jpg
# Processing 7 (58).jpg
# Processing 7 (59).jpg
# Processing 7 (6).jpg
# Processing 7 (60).jpg
# Processing 7 (61).jpg
# Processing 7 (62).jpg
# Processing 7 (63).jpg
# Processing 7 (64).jpg
# Processing 7 (65).jpg
# Processing 7 (66).jpg
# Processing 7 (67).jpg
# Processing 7 (68).jpg
# Processing 7 (69).jpg
# Processing 7 (7).jpg
# Processing 7 (70).jpg
# Processing 7 (71).jpg
# Processing 7 (72).jpg
# Processing 7 (73).jpg
# Processing 7 (74).jpg
# Processing 7 (75).jpg
# Processing 7 (76).jpg
# Processing 7 (77).jpg
# Processing 7 (78).jpg
# Processing 7 (79).jpg
# Processing 7 (8).jpg
# Processing 7 (80).jpg
# Processing 7 (81).jpg
# Processing 7 (82).jpg
# Processing 7 (84).jpg
# Processing 7 (85).jpg
# Processing 7 (86).jpg
# Processing 7 (87).jpg
# Processing 7 (88).jpg
# Processing 7 (89).jpg
# Processing 7 (9).jpg
# Processing 7 (90).jpg
# Processing 7 (91).jpg
# Processing 7 (92).jpg
# Processing 7 (93).jpg
# Processing 7 (94).jpg
# Processing 7 (95).jpg
# Processing 7 (96).jpg
# Processing 7 (97).jpg
# Processing 7 (98).jpg
# Processing 7 (99).jpg
# Processing 8 (1).jpg
# Processing 8 (10).jpg
# Processing 8 (100).jpg
# Processing 8 (101).jpg
# Processing 8 (102).jpg
# Processing 8 (103).jpg
# Processing 8 (104).jpg
# Processing 8 (105).jpg
# Processing 8 (106).jpg
# Processing 8 (107).jpg
# Processing 8 (108).jpg
# Processing 8 (109).jpg
# Processing 8 (11).jpg
# Processing 8 (110).jpg
# Processing 8 (111).jpg
# Processing 8 (112).jpg
# Processing 8 (113).jpg
# Processing 8 (114).jpg
# Processing 8 (115).jpg
# Processing 8 (116).jpg
# Processing 8 (117).jpg
# Processing 8 (118).jpg
# Processing 8 (119).jpg
# Processing 8 (12).jpg
# Processing 8 (13).jpg
# Processing 8 (14).jpg
# Processing 8 (15).jpg
# Processing 8 (16).jpg
# Processing 8 (17).jpg
# Processing 8 (18).jpg
# Processing 8 (19).jpg
# Processing 8 (2).jpg
# Processing 8 (20).jpg
# Processing 8 (21).jpg
# Processing 8 (22).jpg
# Processing 8 (23).jpg
# Processing 8 (24).jpg
# Processing 8 (25).jpg
# Processing 8 (26).jpg
# Processing 8 (27).jpg
# Processing 8 (28).jpg
# Processing 8 (29).jpg
# Processing 8 (3).jpg
# Processing 8 (30).jpg
# Processing 8 (31).jpg
# Processing 8 (32).jpg
# Processing 8 (33).jpg
# Processing 8 (34).jpg
# Processing 8 (35).jpg
# Processing 8 (36).jpg
# Processing 8 (37).jpg
# Processing 8 (38).jpg
# Processing 8 (39).jpg
# Processing 8 (4).jpg
# Processing 8 (40).jpg
# Processing 8 (41).jpg
# Processing 8 (42).jpg
# Processing 8 (43).jpg
# Processing 8 (44).jpg
# Processing 8 (45).jpg
# Processing 8 (46).jpg
# Processing 8 (47).jpg
# Processing 8 (48).jpg
# Processing 8 (49).jpg
# Processing 8 (5).jpg
# Processing 8 (50).jpg
# Processing 8 (51).jpg
# Processing 8 (52).jpg
# Processing 8 (53).jpg
# Processing 8 (54).jpg
# Processing 8 (55).jpg
# Processing 8 (56).jpg
# Processing 8 (57).jpg
# Processing 8 (58).jpg
# Processing 8 (59).jpg
# Processing 8 (6).jpg
# Processing 8 (60).jpg
# Processing 8 (61).jpg
# Processing 8 (62).jpg
# Processing 8 (63).jpg
# Processing 8 (64).jpg
# Processing 8 (65).jpg
# Processing 8 (66).jpg
# Processing 8 (67).jpg
# Processing 8 (68).jpg
# Processing 8 (69).jpg
# Processing 8 (7).jpg
# Processing 8 (70).jpg
# Processing 8 (71).jpg
# Processing 8 (72).jpg
# Processing 8 (73).jpg
# Processing 8 (74).jpg
# Processing 8 (75).jpg
# Processing 8 (76).jpg
# Processing 8 (77).jpg
# Processing 8 (78).jpg
# Processing 8 (79).jpg
# Processing 8 (8).jpg
# Processing 8 (80).jpg
# Processing 8 (81).jpg
# Processing 8 (82).jpg
# Processing 8 (83).jpg
# Processing 8 (84).jpg
# Processing 8 (85).jpg
# Processing 8 (86).jpg
# Processing 8 (87).jpg
# Processing 8 (88).jpg
# Processing 8 (89).jpg
# Processing 8 (9).jpg
# Processing 8 (90).jpg
# Processing 8 (91).jpg
# Processing 8 (92).jpg
# Processing 8 (93).jpg
# Processing 8 (94).jpg
# Processing 8 (95).jpg
# Processing 8 (96).jpg
# Processing 8 (97).jpg
# Processing 8 (98).jpg
# Processing 8 (99).jpg
# Processing 9 (1).jpg
# Processing 9 (10).jpg
# Processing 9 (11).jpg
# Processing 9 (12).jpg
# Processing 9 (13).jpg
# Processing 9 (14).jpg
# Processing 9 (15).jpg
# Processing 9 (16).jpg
# Processing 9 (17).jpg
# Processing 9 (18).jpg
# Processing 9 (19).jpg
# Processing 9 (2).jpg
# Processing 9 (20).jpg
# Processing 9 (21).jpg
# Processing 9 (22).jpg
# Processing 9 (23).jpg
# Processing 9 (24).jpg
# Processing 9 (25).jpg
# Processing 9 (26).jpg
# Processing 9 (27).jpg
# Processing 9 (28).jpg
# Processing 9 (29).jpg
# Processing 9 (3).jpg
# Processing 9 (30).jpg
# Processing 9 (31).jpg
# Processing 9 (32).jpg
# Processing 9 (33).jpg
# Processing 9 (34).jpg
# Processing 9 (35).jpg
# Processing 9 (36).jpg
# Processing 9 (37).jpg
# Processing 9 (38).jpg
# Processing 9 (39).jpg
# Processing 9 (4).jpg
# Processing 9 (40).jpg
# Processing 9 (41).jpg
# Processing 9 (42).jpg
# Processing 9 (43).jpg
# Processing 9 (44).jpg
# Processing 9 (45).jpg
# Processing 9 (46).jpg
# Processing 9 (47).jpg
# Processing 9 (48).jpg
# Processing 9 (49).jpg
# Processing 9 (5).jpg
# Processing 9 (50).jpg
# Processing 9 (51).jpg
# Processing 9 (52).jpg
# Processing 9 (53).jpg
# Processing 9 (54).jpg
# Processing 9 (55).jpg
# Processing 9 (56).jpg
# Processing 9 (57).jpg
# Processing 9 (58).jpg
# Processing 9 (59).jpg
# Processing 9 (6).jpg
# Processing 9 (60).jpg
# Processing 9 (61).jpg
# Processing 9 (62).jpg
# Processing 9 (63).jpg
# Processing 9 (64).jpg
# Processing 9 (65).jpg
# Processing 9 (66).jpg
# Processing 9 (67).jpg
# Processing 9 (68).jpg
# Processing 9 (69).jpg
# Processing 9 (7).jpg
# Processing 9 (70).jpg
# Processing 9 (71).jpg
# Processing 9 (72).jpg
# Processing 9 (73).jpg
# Processing 9 (8).jpg
# Processing 9 (9).jpg
